# %% [markdown]
# # Домашнее задание по модулю 3

# %% [markdown]
# Сегодня мы будем определять качество вина по его параметрам!
#
# Набор данных, которые мы сегодня будем использовать, похож на один из классических датасетов, используемых для проверки алгоритмов машинного обучения. Вот ссылка на оригинальный датасет и его описание: https://archive.ics.uci.edu/ml/datasets/wine+quality
#
# Мы с вами будем использовать немного модифицированную версию датасета; не забудьте скачать его, а также набор данных для проверки из материалов к модулю.

# %%
#импортируем стандартные библиотеки
# %matplotlib inline
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# Давайте посмотрим на датасет

# %%
data = pd.read_csv('hw_data.csv')
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.1              0.20         0.33             7.1      0.043
# 1            5.0              0.28         0.35             1.3      0.058
# 2            5.1              0.26         0.31            14.6      0.120
# 3            5.3              0.17         0.19             1.5      0.042
# 4            6.8              0.27         0.26             2.1      0.046
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 22.0                 163.0   0.9948  3.23       0.66
# 1                 40.0                 174.0   0.9929  3.19       0.78
# 2                 68.0                 144.0   0.9958  3.13       0.54
# 3                 35.0                 178.0   0.9997  2.99       0.39
# 4                 30.0                 110.0   0.9998  3.14       0.47
#
#    alcohol   quality
# 0     11.5  7.786968
# 1      9.6  7.190270
# 2     10.9  7.746242
# 3      9.8  7.342469
# 4     10.1  7.510645

# %% [markdown]
# Как видите, у нас есть разнообразные параметры вина, такие как уровень pH, уровень алкоголя и тд.
#
# Последним параметром идет качество — усредненная оценка вина от нескольких дегустаторов. В отличие от оригинального датасета, качество у нас может быть дробным.
#
# Наша задача — построить модель машинного обучения, которая сможет заменить этих самых дегустаторов.

# %% [markdown]
#  ##### Предобработка данных
#  Сначала выделим целевую функцию из нашего набора данных и удалим ее из самих данных.

# %%
labels = data['quality']
del(data['quality'])

# %% [markdown]
# Раделим нашу выборку на тренировочную и тестовую выборку.
#
# ##### Задание: импортируйте нужную функцию из библиотеки sklearn и вызовите ее
# Пример можно посмотреть в видео №9.

# %%
from sklearn.model_selection import train_test_split
data_train, data_test, labels_train, labels_test = train_test_split(data, labels)

# %% [markdown]
# ##### Построим модель линейной регрессии
# 1) Импортируем модель из библиотеки sklearn

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# 2) Обучим модель на тестовых данных

# %%
#model = LinearRegression()
#model = DecisionTreeRegressor(max_depth = 14)
model = RandomForestRegressor()
model.fit(data_train, labels_train)
# Out:
# /home/kalan/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %% [markdown]
# 3) Выполним предсказание на тестовых данных

# %%
prediction = model.predict(data_test)

# %% [markdown]
# 4) Посчитаем метрику "средний квадрат ошибки". Для этого воспользуемся стандартной функцией из библиотеки sklearn

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(prediction, labels_test)
# Out:
# 0.03403499366391891

# %% [markdown]
# ### Задание: обучить "хорошую" модель
# Замените линейную регрессию на другие регрессионные модели, упоминавшиеся в занятии. Попробуйте такие модели, как Дерево принятия решений (DecisionTree) и Случайные Леса (RandomForest).
#
# Для дерева принятия решений попробуйте разные параметры глубины дерева (max_depth)
#
# Для Случайного леса можно попробовать разную глубину дерева (max_dept) и количество деревьев (n_estimators)
#
# Для получения зачета вам необходимо обучить модель, которая покажет результат среднего квадрата ошибки отклонения менее, чем 0.06.
#
# Примеры обучения этих моделей ищите в видео №10

# %% [markdown]
# # Выполним предсказание для "контрольной" выборки
# Загрузим "контрольный" датасет и выполним предсказание

# %%
data_control = pd.read_csv('data_to_estimate.csv')
prediction = model.predict(data_control)

# %% [markdown]
# Распечатаем разультат:
# ### Строчку с распечатанными предсказаниями скопируйте в EdX
# ##### Результат будет засчитан, если метрика mean_squared_error по контрольным данным оказалась меньше 0.06

# %%
print(",".join(["{:.3f}".format(num) for num in prediction]))
# Out:
# 7.591,8.117,7.450,7.899,7.557,7.378,7.641,6.509,7.703,7.483,6.874,7.134,8.813,6.273,7.940,6.859,6.888,7.252,7.316,7.103,9.131,8.202,7.483,7.518,7.736,7.408,7.251,6.872,6.469,8.557,7.675,8.453,7.453,6.727,7.409,8.080,7.092,8.196,7.216,7.661,6.175,7.408,7.279,7.106,6.855,8.104,7.892,7.407,8.375,8.279,7.843,6.992,7.146,7.767,6.697,7.421,6.975,6.924,6.392,6.841,7.723,7.154,7.215,6.987,7.519,6.449,7.749,7.211,7.169,7.841,7.458,7.056,7.273,8.714,6.949,7.939,7.363,7.631,7.554,7.222,7.779,7.741,5.989,8.192,6.295,8.487,8.056,7.541,6.510,7.039,7.411,6.278,7.756,8.195,8.216,6.923,8.097,7.417,8.563,8.719,6.819,7.181,7.118,7.485,7.352,6.970,7.613,8.876,7.657,7.048,7.181,8.106,8.149,7.867,7.503,8.405,7.091,7.460,7.683,8.288,7.407,7.181,6.977,7.312,7.336,7.846,7.633,7.435,7.723,6.751,7.282,7.450,8.322,7.903,7.905,7.563,7.146,8.974,7.879,8.441,8.831,7.395,7.216,7.142,8.432,7.728,6.246,7.866,6.606,7.544,8.824,7.574,7.186,7.737,7.864,7.609,7.140,7.227,7.973,8.092,7.403,6.707,8.986,8.053,7.280,7.605,7.476,7.227,8.455,7.959,8.767,7.259,8.022,8.302,8.679,7.018,6.896,7.230,7.488,6.739,7.317,7.326,7.376,6.835,7.198,8.789,8.087,9.087,7.980,8.616,7.989,7.162,6.826,7.259,7.343,7.091,7.237,7.477,7.167,8.027,7.683,7.480,8.775,7.831,6.912,7.577,8.489,8.994,8.836,7.690,6.971,7.266,8.118,7.671,7.041,6.660,7.343,7.505,7.777,7.489,7.560,7.774,8.337,8.100,7.646,7.511,8.293,7.789,7.424,7.187,8.401,7.187,7.941,7.120,6.927,6.397,7.273,7.584,8.372,7.519,6.964,7.419,6.966,6.523,6.669,7.524,7.079,7.566,6.601,6.874,8.517,6.971,7.230,8.913,7.904,7.687,7.260,6.869,8.405,7.701,7.527,7.924,7.250,7.787,6.963,7.580,7.113,8.885,6.865,6.841,7.067,7.307,7.282,7.130,7.240,7.516,6.590,7.495,7.453,7.526,8.760,7.315,7.402,7.714,6.220,7.077,7.781,6.819,8.303,7.597,7.813,7.852,7.750,7.713,7.736,6.826,7.491,7.633,6.785,7.331,8.399,8.130,7.288,7.723,7.717,7.502,9.005,8.803,6.324,8.500,7.344,8.828,6.972,7.194,8.512,7.593,7.391,7.689,6.340,6.681,7.813,7.375,8.825,7.493,7.953,5.920,6.747,8.502,6.219,7.738,7.081,8.463,7.012,7.562,7.494,7.270,7.534,7.110,7.314,7.201,8.190,7.801,7.346,7.365,7.006,7.243,7.487,8.464,7.648,7.928,8.915,7.648,7.780,8.024,7.377,7.170,7.289,7.237,7.666,7.488,7.013,7.590,7.810,7.507,7.306,7.773,7.092,7.057,6.845,7.613,8.270,7.474,8.211,7.743,7.994,8.625,7.643,8.039,8.562,8.691,7.277,7.030,6.745,7.605,7.466,7.456,7.455,6.870,7.647,7.759,5.846,6.960,7.760,7.091,7.400,8.961,7.243,7.330,7.675,7.628,8.580,7.169,8.445,7.641,6.807,6.237,7.072,7.803,7.499,7.154,7.835,7.081,7.481,7.992,7.906,7.459,6.928,7.015,8.759,8.466,7.151,8.111,8.067,7.162,6.478,7.495,6.618,7.029,6.987,7.312,7.707,6.939,7.785,7.605,7.164,7.099,7.759,7.932,7.603,6.847,7.855,7.784,6.649,8.954,6.922,8.165,7.844,8.768,7.465,6.412,7.548,7.057,8.426,7.862,8.388,7.504,7.290,7.766,8.131,8.423,7.777,6.638,7.671,7.535,7.513,7.030,7.013,7.402,8.062,7.141,7.468,7.333,7.050,7.710,7.303,6.827,7.824,6.373,7.764,7.190,6.554,8.425,7.460,5.989,8.399,6.136,7.571,7.546,7.823,7.774,7.425,7.454,7.108,6.555,7.149,6.996,6.539,7.227,7.415,7.046,7.426,8.031,9.011,6.114,7.622,7.703,6.713,7.277,7.322,7.577,6.800,7.359,6.753,7.716,7.434,7.846,7.361,7.613,7.583,7.281,6.678,8.299,7.295,7.303,6.475,7.161,7.611,7.588,6.616,7.240,7.147,7.977,7.264,8.348,7.093,7.711,6.472,6.306,7.651,7.550,6.498,7.990,7.320,7.544,7.978,8.334,7.718,7.822,6.926,7.510,7.637,7.359,6.778,7.300,7.862,7.359,8.556,7.636,7.996,8.009,6.834,7.430,7.466,8.296,6.943,7.812,6.236,7.125,7.472,7.900,7.480,7.715,7.276,8.473,6.877,7.850,7.633,8.292,8.177,7.145,7.373,7.204,7.011,6.187,7.312,7.502,8.280,6.935,7.951,7.736,8.205,8.045,7.503,8.215,7.633,7.217,6.920,7.303,8.645,7.659,6.821,7.309,7.492,6.256,8.279,8.734,7.573,8.635,8.885,8.154,7.673,7.897,7.679,7.669,6.973,7.369,6.886,7.223,8.131,7.271,7.697,6.453,7.405,7.154,7.290,7.500,7.759,7.423,6.973,8.187,7.264,7.497,7.126,6.873,6.295,6.922,7.386,7.344,8.264,7.499,8.575,7.022,7.079,8.519,7.204,7.281,7.776,6.980,6.832,7.686,6.747,8.298,6.539,7.222,7.411,7.041,8.381,6.758,7.323,7.767,7.259,7.797,7.204,7.252,7.495,6.952,7.12 ...
